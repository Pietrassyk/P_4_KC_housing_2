# %%
# !ls
# Out:
# LICENSE
# Mod4_Project_Tino_MaryJo.ipynb
# README.md
# column_names.md
# kc_housing_data_for_feat_engineering_lab.csv

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('kc_housing_data_for_feat_engineering_lab.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21600 entries, 0 to 21599
# Data columns (total 25 columns):
# id               21600 non-null int64
# date             21600 non-null object
# price            21600 non-null float64
# bedrooms         21600 non-null int64
# bathrooms        21600 non-null float64
# sqft_living      21600 non-null int64
# sqft_lot         21600 non-null int64
# floors           21600 non-null float64
# waterfront       21600 non-null int64
# view             21600 non-null int64
# condition        21600 non-null int64
# grade            21600 non-null int64
# sqft_above       21600 non-null int64
# sqft_basement    21600 non-null int64
# yr_built         21600 non-null int64
# yr_renovated     21600 non-null int64
# zipcode          21600 non-null int64
# lat              21600 non-null float64
# long             21600 non-null float64
# sqft_living15    21600 non-null int64
# sqft_lot15       21600 non-null int64
# ...

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0         3       1.00         1180
# 1  6414100192  2014-12-09  538000.0         3       2.25         2570
# 2  5631500400  2015-02-25  180000.0         2       1.00          770
# 3  2487200875  2014-12-09  604000.0         4       3.00         1960
# 4  1954400510  2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  yr_old  year_sold  since_sold  \
# ...

# %%
#Count number of zipcodes
df.zipcode.value_counts()
# Out:
# 98103    601
# 98038    590
# 98115    583
# 98052    574
# 98117    553
# 98042    548
# 98034    545
# 98118    508
# 98023    499
# 98006    497
# 98133    494
# 98059    468
# 98058    455
# 98155    445
# 98074    441
# 98033    431
# 98027    412
# 98125    410
# 98056    406
# 98053    405
# 98001    362
# 98075    359
# 98126    354
# 98092    351
# 98144    343
# 98106    335
# 98116    330
# 98029    321
# 98199    317
# 98004    314
#         ...
# 98168    269
# 98112    269
# 98055    268
# 98107    266
# 98136    263
# 98178    262
# 98030    256
# 98177    255
# 98166    254
# 98022    234
# 98105    229
# 98045    221
# 98002    199
# 98077    198
# 98011    195
# 98019    190
# 98108    186
# 98119    184
# 98005    168
# 98007    141
# 98188    136
# 98032    125
# 98014    124
# 98070    118
# 98109    109
# 98102    104
# 98010    100
# 98024     81
# 98148     57
# 98039     47
# Name: zipcode, Length: 70, dtype: int64

# %%
dfzip = df.zipcode.unique()

# %%
# Calculated field created for price/sqft
df['price_sqft'] = df['price']/ df['sqft_living']

# %%
df.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21595   263000018  2014-05-21  360000.0         3       2.50         1530
# 21596  6600060120  2015-02-23  400000.0         4       2.50         2310
# 21597  1523300141  2014-06-23  402101.0         2       0.75         1020
# 21598   291310100  2015-01-16  400000.0         3       2.50         1600
# 21599  1523300157  2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  zipcode      lat     long  \
# 21595      1131     3.0           0     0  ...    98103  47.6993 -122.346
# 21596      5813     2.0           0     0  ...    98146  47.5107 -122.362
# 21597      1350     2.0           0     0  ...    98144  47.5944 -122.299
# 21598      2388     2.0           0     0  ...    98027  47.5345 -122.069
# 21599      1076     2.0           0     0  ...    98144  47.5941 -122.299
#
# ...

# %%
grouped = df.groupby('zipcode')
grouped_psqft = grouped['price_sqft'].agg(np.mean)

# %%
grouped_psqft.tail()
# Out:
# zipcode
# 98177    292.918745
# 98178    189.172528
# 98188    169.007306
# 98198    178.428610
# 98199    376.546345
# Name: price_sqft, dtype: float64

# %%
dfNew = df.merge(grouped_psqft, left_on=['zipcode'], right_on=['zipcode'])
dfNew.tail()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 21595  2525049086  2014-10-03  2720000.0         4       3.25         3990
# 21596  2525049113  2014-07-25  1950000.0         4       3.50         4065
# 21597  3262300485  2015-04-21  2250000.0         5       5.25         3410
# 21598  6447300365  2014-11-13  2900000.0         5       4.00         5190
# 21599  3262300818  2015-02-27  1865000.0         4       3.75         3790
#
#        sqft_lot  floors  waterfront  view  ...      lat     long  \
# 21595     18115     2.0           0     0  ...  47.6177 -122.229
# 21596     18713     2.0           0     0  ...  47.6209 -122.237
# 21597      8118     2.0           0     0  ...  47.6295 -122.236
# 21598     14600     2.0           0     1  ...  47.6102 -122.225
# 21599      8797     2.0           0     0  ...  47.6351 -122.236
#
#        sqft_living15  sqft_lot15  yr_old  year_sold  since_sold  price_log  \
# ...

# %%
dfNew.rename(columns={'price_sqft_y':'price_sqft_mean_zip'}, inplace=True)

# %%
dfNew.tail()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 21595  2525049086  2014-10-03  2720000.0         4       3.25         3990
# 21596  2525049113  2014-07-25  1950000.0         4       3.50         4065
# 21597  3262300485  2015-04-21  2250000.0         5       5.25         3410
# 21598  6447300365  2014-11-13  2900000.0         5       4.00         5190
# 21599  3262300818  2015-02-27  1865000.0         4       3.75         3790
#
#        sqft_lot  floors  waterfront  view  ...      lat     long  \
# 21595     18115     2.0           0     0  ...  47.6177 -122.229
# 21596     18713     2.0           0     0  ...  47.6209 -122.237
# 21597      8118     2.0           0     0  ...  47.6295 -122.236
# 21598     14600     2.0           0     1  ...  47.6102 -122.225
# 21599      8797     2.0           0     0  ...  47.6351 -122.236
#
#        sqft_living15  sqft_lot15  yr_old  year_sold  since_sold  price_log  \
# ...

# %%
# Making a more compact dataframe to work with, using list comprehension to select columns of interest. Creating a
#   function that will be reused in the analysis
def select_columns(data_frame, column_values):
    new_frame = data_frame.loc[:, column_values]
    return new_frame

# %%
selected_columns = ['price', 'price_sqft_x', 'price_sqft_mean_zip', 'zipcode']
dfNew_slim = select_columns(dfNew, selected_columns)
dfNew_slim.tail()
# Out:
#            price  price_sqft_x  price_sqft_mean_zip  zipcode
# 21595  2720000.0    681.704261           564.629856    98039
# 21596  1950000.0    479.704797           564.629856    98039
# 21597  2250000.0    659.824047           564.629856    98039
# 21598  2900000.0    558.766859           564.629856    98039
# 21599  1865000.0    492.084433           564.629856    98039

# %%
len(dfNew.groupby('zipcode').mean().sort_values(by='price_sqft_mean_zip'))
# Out:
# 70

# %%
dfNew.price_sqft_mean_zip.value_counts().shape
# Out:
# (70,)

# %%
for zip in df.index:
   df.loc[idx,'data-3'] = df.loc[idx, 'data-2']*df_lookup.at[idx.hour]

# %%
selected_columns = ['uuid', 'course_offering_uuid', 'number', 'schedule_uuid']
dfSections_slim = select_columns(dfSections, selected_columns)
dfSections_slim.tail()
